# %%
feedback_list = [
    "Shipping was prompt and met our deadline perfectly.",
    "There were delays in shipping which affected our project timelines.",
    "Competitive pricing allowed us to stay within budget.",
    "Recent price increases have impacted our purchasing decisions.",
    "Customer service was exceptional, responsive, and helpful.",
    "We experienced difficulties reaching customer service during peak hours.",
    "The product quality exceeded our expectations.",
    "Some products received had minor defects that required replacements.",
    "Communication regarding order status was clear and frequent.",
    "There was a lack of proactive communication about delays in production.",
    "Products were well-packaged to prevent damage.",
    "Packaging could be improved to reduce waste and ensure product safety.",
    "The supplier was accommodating to our changing requirements.",
    "There was inflexibility when it came to modifying our order.",
    "Technical support provided thorough assistance when setting up the equipment.",
    "We encountered challenges with accessing timely technical support.",
    "Returns and refunds were processed quickly and efficiently.",
    "We faced complications with the return process due to unclear instructions.",
    "Documentation provided with the products was comprehensive and easy to follow.",
    "Some essential documentation was missing from our shipment."
    "The delivery was faster than expected.",
    "The shipping costs were reasonable compared to competitors.",
    "Customer service representatives were courteous and knowledgeable.",
    "There were delays in response from customer service.",
    "The quality of the product was consistent with our expectations.",
    "We received products that were damaged during shipping.",
    "Communication about product availability was clear and timely.",
    "There was confusion about the pricing of our order.",
    "The packaging protected the products well.",
    "Packaging materials were excessive and environmentally unfriendly.",
    "Changes to our order were handled smoothly.",
    "We encountered resistance when requesting changes to our order.",
    "Technical support resolved our issue quickly and effectively.",
    "We had difficulty reaching technical support when needed.",
    "Returns were processed smoothly with clear instructions.",
    "There was a delay in receiving our refund after returning a product.",
    "The documentation provided was thorough and helpful.",
    "Critical documentation was missing from our shipment.",
    "The supplier proactively informed us of delays in shipping.",
    "We were not notified of a significant delay in shipping.",
    "Costs were transparent and understandable.",
    "We encountered unexpected charges on our invoice.",
    "Customer service went above and beyond to resolve our issue.",
    "Our issue was not adequately addressed by customer service.",
    "Product quality met industry standards.",
    "Product quality did not meet our expectations.",
    "Communication throughout the ordering process was excellent.",
    "We were left in the dark about the status of our order.",
    "The packaging was eco-friendly and sustainable.",
    "The packaging was excessive and wasteful.",
    "The supplier accommodated our urgent shipping request.",
    "Our urgent shipping request was not accommodated.",
    "Technical support was available 24/7.",
    "Technical support had limited availability.",
    "Refunds were processed promptly and efficiently.",
    "We experienced delays in receiving our refund.",
    "The documentation included helpful troubleshooting tips.",
    "The documentation lacked necessary troubleshooting information.",
    "The supplier offered competitive pricing.",
    "We found cheaper pricing from another supplier.",
    "Customer service provided personalized support.",
    "Customer service responses were generic and unhelpful.",
    "Product quality exceeded our expectations.",
    "Product quality did not meet our expectations.",
    "The supplier provided updates throughout the manufacturing process.",
    "We were not updated on the progress of our order.",
    "The shipping carrier used was reliable and timely.",
    "We had issues with the reliability of the shipping carrier.",
    "The supplier offered flexible payment terms.",
    "We encountered rigid payment terms with the supplier.",
    "The supplier offered discounts for bulk orders.",
    "We were not offered discounts for bulk orders.",
    "Customer service followed up after resolving our issue.",
    "We did not receive any follow-up from customer service.",
    "Product specifications were accurately described.",
    "Product specifications did not match what was delivered.",
    "We received personalized recommendations from customer service.",
    "Customer service did not provide any recommendations.",
    "The supplier offered a wide range of products.",
    "The supplier's product range was limited.",
    "The supplier provided detailed shipping tracking information.",
    "We were unable to track our shipment effectively.",
    "The supplier provided environmentally friendly packaging options.",
    "Packaging materials were not environmentally friendly.",
    "The supplier provided free samples of products.",
    "We were charged for product samples.",
    "Product customization options were extensive.",
    "We encountered limitations when customizing our order.",
    "The supplier informed us of potential delays in production.",
    "We were not informed of potential delays in production.",
    "The supplier provided clear instructions for product assembly.",
    "We struggled to assemble the product due to unclear instructions.",
    "The supplier offered ongoing technical support after purchase.",
    "We did not receive ongoing technical support after purchase.",
    "The supplier offered expedited shipping options.",
    "Expedited shipping options were not available from the supplier.",
    "The supplier provided warranty information upfront.",
    "We had to inquire about warranty information.",
    "Customer service representatives were available via multiple channels.",
    "We could only contact customer service via email.",
    "Product quality was consistent across multiple orders.",
    "We experienced variations in product quality across orders.",
    "The supplier offered a user-friendly online ordering system.",
    "We encountered difficulties navigating the online ordering system.",
    "The supplier offered discounts for repeat customers.",
    "We were not offered discounts as repeat customers.",
    "The supplier informed us of product recalls promptly.",
    "We were not informed of a product recall.",
    "The supplier offered a satisfaction guarantee.",
    "We were not offered a satisfaction guarantee.",
    "The supplier offered product samples upon request.",
    "We had to pay for product samples.",
    "Shipping was prompt and arrived earlier than expected.",
    "The cost was competitive and fit well within our budget.",
    "Customer service was responsive and helpful throughout the process.",
    "The product quality exceeded our expectations.",
    "Unfortunately, shipping was delayed without prior notice.",
    "The cost was higher than anticipated based on the initial quote.",
    "Customer service was difficult to reach and unhelpful.",
    "There were issues with product quality upon arrival.",
    "Shipping packaging was inadequate, resulting in damaged goods.",
    "The cost was reasonable, considering the quality of the product.",
    "Customer service went above and beyond to resolve our issues.",
    "Product quality was consistent and met our standards.",
    "Shipping costs were higher than expected, impacting our budget.",
    "The initial cost estimate was inaccurate, leading to budgetary issues.",
    "Customer service was friendly and efficient in handling our inquiries.",
    "The quality of the product did not meet our specifications.",
    "Shipping was fast, but packaging could have been more secure.",
    "The overall cost was economical compared to other suppliers.",
    "Customer service was knowledgeable and provided valuable insights.",
    "Product quality was excellent, and durability exceeded our expectations."
    "Shipping was on time and well-coordinated.",
    "The cost was reasonable, and we appreciated the discounts offered.",
    "Customer service was attentive and resolved our issues promptly.",
    "The product quality was excellent, and our customers were satisfied.",
    "Shipping took longer than expected, causing delays in our project.",
    "The cost was higher than competitors for similar products.",
    "Customer service was slow to respond and not very helpful.",
    "There were minor issues with product quality, but overall acceptable.",
    "Shipping packaging was secure, and items arrived in perfect condition.",
    "The cost was justified by the superior quality of the product.",
    "Customer service was friendly and accommodating to our needs.",
    "Product quality met our specifications and received positive feedback.",
    "Shipping costs were prohibitive and affected our profit margins.",
    "The initial cost estimate was accurate, which helped with budgeting.",
    "Customer service provided clear instructions and support throughout.",
    "The product quality was inconsistent; some items were defective.",
    "Shipping was efficient, but the tracking information was unclear.",
    "The overall cost was competitive, making it a good value.",
    "Customer service was knowledgeable and assisted with technical questions.",
    "Product quality was outstanding; no issues reported by end-users.",
    "Shipping was delayed due to unforeseen circumstances beyond control.",
    "The cost was lower than expected, which was a pleasant surprise.",
    "Customer service representatives were polite but lacked expertise.",
    "Product quality was average; met our minimum requirements.",
    "Shipping packaging was inadequate, resulting in damaged goods.",
    "The cost was justified given the premium features of the product.",
    "Customer service handled our complaints professionally and promptly.",
    "Product quality exceeded expectations; received positive feedback.",
    "Shipping costs were reasonable, considering the distance.",
    "The initial cost estimate was misleading, causing budgetary concerns.",
    "Customer service was available 24/7 and resolved issues quickly.",
    "The product quality was poor; several items had manufacturing defects.",
    "Shipping was fast, and the tracking information was accurate.",
    "The overall cost was high, but justified by the product's uniqueness.",
    "Customer service provided personalized attention and follow-up.",
    "Product quality was subpar compared to previous orders.",
    "Shipping was free, which saved us on additional costs.",
    "The cost was competitive, but there were unexpected fees at checkout.",
    "Customer service was courteous but lacked follow-through on promises.",
    "Product quality was exceptional; received compliments from customers.",
    "Shipping was delayed due to weather conditions, understandable but inconvenient.",
    "The cost was higher than expected, impacting our project budget.",
    "Customer service was attentive and resolved our concerns satisfactorily.",
    "Product quality was inconsistent; some units were flawed.",
    "Shipping was quick, and the packaging was secure.",
    "The overall cost was affordable, and the payment process was smooth.",
    "Customer service representatives were helpful and knowledgeable.",
    "Product quality was as described; no issues reported by end-users.",
    "Shipping costs were reasonable compared to industry standards.",
    "The initial cost estimate was accurate, which helped us plan effectively.",
    "Customer service responded promptly and resolved our issue efficiently.",
    "The product quality met our expectations; no complaints from customers.",
    "Shipping was delayed due to logistical issues beyond their control.",
    "The cost was competitive, and the bulk discount was appreciated.",
    "Customer service was excellent; they provided detailed information.",
    "Product quality was excellent; durable and well-made.",
    "Shipping was slower than expected, but items arrived in good condition.",
    "The overall cost was higher than anticipated, impacting our budget.",
    "Customer service was responsive and addressed our concerns promptly.",
    "Product quality was satisfactory; met our specifications.",
    "Shipping packaging was sturdy, and products arrived undamaged.",
    "The cost was reasonable for the quality received.",
    "Customer service was helpful and provided updates on our order.",
    "Product quality was consistent and met our standards.",
    "Shipping costs were higher than expected, affecting our budget.",
    "The initial cost estimate was accurate, which helped with budget planning.",
    "Customer service was courteous and handled our issue professionally.",
    "The product quality was subpar; several units were defective.",
    "Shipping was on time, but the packaging could have been better.",
    "The cost was justified by the durability and performance of the product.",
    "Customer service went above and beyond to resolve our concerns.",
    "Product quality was excellent; exceeded our expectations.",
    "Shipping costs were reasonable, and delivery was timely.",
    "The initial cost estimate was accurate, which facilitated our decision-making.",
    "Customer service was responsive and assisted with our inquiries.",
    "The product quality was exceptional; received positive feedback from users.",
    "Shipping was delayed, but customer service provided timely updates.",
    "The cost was competitive, and the payment process was straightforward.",
    "Customer service was knowledgeable and provided helpful advice.",
    "Product quality was satisfactory; met our requirements.",
    "Shipping packaging was secure, and products arrived in good condition.",
    "The cost was reasonable for the quality received.",
    "Customer service was helpful and provided updates on our order.",
    "Product quality was consistent and met our standards.",
    "Shipping costs were higher than expected, affecting our budget.",
    "The initial cost estimate was accurate, which helped with budget planning.",
    "Customer service was courteous and handled our issue professionally.",
    "The product quality was subpar; several units were defective.",
    "Shipping was on time, but the packaging could have been better.",
    "The cost was justified by the durability and performance of the product.",
    "Customer service went above and beyond to resolve our concerns.",
    "Product quality was excellent; exceeded our expectations.",
    "Shipping costs were reasonable, and delivery was timely.",
    "The initial cost estimate was accurate, which facilitated our decision-making.",
    "Customer service was responsive and assisted with our inquiries.",
    "The product quality was exceptional; received positive feedback from users.",
    "Shipping was delayed, but customer service provided timely updates.",
    "The cost was competitive, and the payment process was straightforward.",
    "Customer service was knowledgeable and provided helpful advice.",
    "Product quality was satisfactory; met our requirements.",
    "Shipping packaging was secure, and products arrived in good condition."
]

# %%
import numpy as np
import random
from faker import Faker
from datetime import datetime as dt

fake = Faker()
Faker.seed(123)
np.random.seed(123)
random.seed(123)

# %%
store_names = ["Playful Pals Toy Emporium", "Whimsy Wonderland Toys", "Marvelous Miniatures", "ToyBox Treasures", "Giggle Gadget Toys", 
               "Dreamy Dollhouse Delights", "Twinkle Town Toys", "Magic Moments Toy Shop", "Starlight Stuffed Animals",
              ]

feedback_df = \
(pd.DataFrame(feedback_list, columns = ['feedback'])
 .assign(
     store_name = np.random.choice(store_names, size=len(feedback)),
     date = [fake.date_time_between(dt(2024,1,1), dt(2024,6,30)).date() for row in range(len(feedback))])
 .loc[:,['store_name','date','feedback']]
 .sort_values(by = 'date')
 .reset_index(drop = True)
 .reset_index()
 .rename(columns = {'index': 'id'})
)

feedback_df
# Out:
#       id                 store_name        date  \
# 0      0  Playful Pals Toy Emporium  2024-01-01
# 1      1       Marvelous Miniatures  2024-01-02
# 2      2  Dreamy Dollhouse Delights  2024-01-02
# 3      3  Playful Pals Toy Emporium  2024-01-04
# 4      4  Starlight Stuffed Animals  2024-01-05
# ..   ...                        ...         ...
# 226  226     Magic Moments Toy Shop  2024-06-27
# 227  227     Magic Moments Toy Shop  2024-06-28
# 228  228          Twinkle Town Toys  2024-06-28
# 229  229     Magic Moments Toy Shop  2024-06-28
# 230  230  Playful Pals Toy Emporium  2024-06-29
#
#                                               feedback
# 0    Packaging could be improved to reduce waste an...
# 1    Unfortunately, shipping was delayed without pr...
# 2    Shipping costs were reasonable compared to ind...
# 3    There was a lack of proactive communication ab...
# 4    Customer service was attentive and resolved ou...
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Create tokenizer object
# stop_words = 'english' -> remove words such as 'the', 'and', etc
# min_df = 5 -> each token/word must appear in at least 5 documents
# max_df = 0.75 -> each toeken/word cannot appear in more than 75% of the documents
tfidf_vectorizer = TfidfVectorizer(stop_words = 'english', max_df = 0.95, min_df = 2)

# Tokenize and perform TF-IDF calculation on dataset
# TF-IDF normalizes infrequent words to be more 'important' while demphasizing more frequent words
doc_term_matrix = tfidf_vectorizer.fit_transform(feedback['feedback'])

doc_term_matrix.shape
# Out:
# (231, 185)

# %%
import pandas as pd
from sklearn.decomposition import LatentDirichletAllocation

# Learn X topics from the text documents
num_topics = 4
lda_topic_model = LatentDirichletAllocation(n_components = num_topics, random_state = 123)

# Train the LDA model and get the document topic assignments
doc_topic_matrix = lda_topic_model.fit_transform(doc_term_matrix)

# Display in pandas dataframe
col_names = [f'Topic {x}' for x in range(1, num_topics + 1)]
doc_topic_df = pd.DataFrame(doc_topic_matrix, columns = col_names)
# Out:
#     Topic 1   Topic 2   Topic 3   Topic 4
# 0  0.098868  0.713451  0.093767  0.093913
# 1  0.089232  0.738601  0.087040  0.085126
# 2  0.465993  0.350579  0.091722  0.091706
# 3  0.250000  0.250000  0.250000  0.250000
# 4  0.079041  0.079695  0.761129  0.080135
# 5  0.079823  0.080679  0.084042  0.755457
# 6  0.085053  0.085890  0.085966  0.743091
# 7  0.740203  0.084027  0.090813  0.084956
# 8  0.083656  0.083657  0.084361  0.748326
# 9  0.091750  0.093275  0.717688  0.097287

# %%
# Display the top X words for each topic
num_words = 15

for topic, words in enumerate(lda_topic_model.components_):
    word_total = words.sum()              # Get the total word weight for topic
    sorted_words = words.argsort()[::-1]  # Sort in descending order
    print(f'\nTopic {topic + 1:02d}')     # Print the topic
    for i in range(0, num_words):         # Print topic's top 10 words
        word = tfidf_vectorizer.get_feature_names_out()[sorted_words[i]]
        word_weight = words[sorted_words[i]] 
        print(f'  {word} ({word_weight:.3f})')
# Out:
# Topic 01
#   cost (8.489)
#   shipping (7.224)
#   products (5.975)
#   costs (5.241)
#   reasonable (4.583)
#   packaging (4.553)
#   expected (4.334)
#   competitive (4.082)
#   supplier (3.714)
#   friendly (3.449)
#   process (3.415)
#   higher (3.365)
#   budget (3.294)
#   overall (3.214)
#   arrived (3.041)
#
# Topic 02
#   shipping (5.698)
#   met (5.329)
#   product (4.161)
#   initial (3.779)
#   packaging (3.596)
#   information (3.549)
#   estimate (3.380)
#   pricing (3.070)
#   accurate (3.050)
#   promptly (3.043)
#   delayed (2.888)
#   quality (2.870)
#   supplier (2.858)
#   standards (2.854)
#   concerns (2.649)
#
# Topic 03
#   customer (8.991)
#   service (8.991)
#   issue (3.728)
#   quality (3.629)
#   technical (3.541)
#   knowledgeable (3.406)
#   helpful (3.305)
#   received (3.266)
#   support (2.830)
#   representatives (2.476)
#   product (2.476)
#   delays (2.388)
#   provided (2.324)
#   courteous (2.249)
#   exceptional (2.242)
#
# Topic 04
# ...

# %%
topic_df = \
(doc_topic_df
 .rename(columns = {
     'Topic 1': 'Cost',
     'Topic 2': 'Shipping',
     'Topic 3': 'Customer Service',
     'Topic 4': 'Quality'})
 .mul(100).round(2)
 .assign(max_topic = lambda df: df.idxmax(axis=1))
 .reset_index()
 .rename(columns = {'index': 'id'})
)
topic_df
# Out:
#       id   Cost  Shipping  Customer Service  Quality         max_topic
# 0      0   9.89     71.35              9.38     9.39          Shipping
# 1      1   8.92     73.86              8.70     8.51          Shipping
# 2      2  46.60     35.06              9.17     9.17              Cost
# 3      3  25.00     25.00             25.00    25.00              Cost
# 4      4   7.90      7.97             76.11     8.01  Customer Service
# ..   ...    ...       ...               ...      ...               ...
# 226  226   7.69      8.47              7.36    76.48           Quality
# 227  227  76.54      7.83              7.81     7.81              Cost
# 228  228   7.43      7.44             77.42     7.71  Customer Service
# 229  229   7.98     75.51              8.10     8.40          Shipping
# 230  230  79.09      7.02              6.94     6.95              Cost
#
# [231 rows x 6 columns]

# %%
# Calculate Perplixity by Topic Count
# Topic Modeling with LDA requires user to input number of topic count
# We can use Perplexity to find the most optimal topic count
topic_nums = range(2, 11)
perplexity = []
for topics in topic_nums:
    lda = LatentDirichletAllocation(n_components = topics, random_state = 123)
    lda.fit(doc_term_matrix)
    perplexity.append(lda.perplexity(doc_topic_matrix))
    
import seaborn as sns

# Plot perplexity by topic count
ax = sns.lineplot(x = topic_nums, y = perplexity, marker = 'o')

# Add labels
ax.set_title('Perplexity by Topic Count')
ax.set_xlabel('Topic Count')
ax.set_ylabel('Perplexity')
# Out:
# C:\Users\cneva\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\cneva\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Perplexity')

# %% [markdown]
# ## Sentiment Analysis

# %%
import nltk

# %%
example = feedback_list[0]
example
# Out:
# 'Shipping was prompt and met our deadline perfectly.'

# %%
tokens = nltk.word_tokenize(example)
tokens
# Out:
# ['Shipping',
#  'was',
#  'prompt',
#  'and',
#  'met',
#  'our',
#  'deadline',
#  'perfectly',
#  '.']

# %%
tagged = nltk.pos_tag(tokens)
tagged
# Out:
# [('Shipping', 'NN'),
#  ('was', 'VBD'),
#  ('prompt', 'JJ'),
#  ('and', 'CC'),
#  ('met', 'VBD'),
#  ('our', 'PRP$'),
#  ('deadline', 'NN'),
#  ('perfectly', 'RB'),
#  ('.', '.')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   (GPE Shipping/NN)
#   was/VBD
#   prompt/JJ
#   and/CC
#   met/VBD
#   our/PRP$
#   deadline/NN
#   perfectly/RB
#   ./.)

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('I am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores('This is the worst thing ever.')
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.6369}

# %%
# Run the polarity score on the entire dataset
res = {}
for i, row in tqdm(feedback_df.iterrows(), total=len(feedback_df)):
    text = row['feedback']
    myid = row['id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/231 [00:00<?, ?it/s]

# %%
sentiment_df = \
(pd.DataFrame(res)
 .T
 .reset_index().rename(columns ={'index': 'id'})
)
sentiment_df
# Out:
#       id    neg    neu    pos  compound
# 0      0  0.153  0.383  0.464    0.6908
# 1      1  0.462  0.538  0.000   -0.5106
# 2      2  0.000  1.000  0.000    0.0000
# 3      3  0.176  0.611  0.214    0.1280
# 4      4  0.000  0.825  0.175    0.1779
# ..   ...    ...    ...    ...       ...
# 226  226  0.000  0.531  0.469    0.6486
# 227  227  0.000  1.000  0.000    0.0000
# 228  228  0.000  0.619  0.381    0.5719
# 229  229  0.293  0.707  0.000   -0.4404
# 230  230  0.000  1.000  0.000    0.0000
#
# [231 rows x 5 columns]

# %%
#feedback_df_final = \
(feedback_df
 .merge(topic_df, how = 'left', on = 'id')
 .merge(sentiment_df, how = 'left', on = 'id')
)
# Out:
#       id                 store_name        date  \
# 0      0  Playful Pals Toy Emporium  2024-01-01
# 1      1       Marvelous Miniatures  2024-01-02
# 2      2  Dreamy Dollhouse Delights  2024-01-02
# 3      3  Playful Pals Toy Emporium  2024-01-04
# 4      4  Starlight Stuffed Animals  2024-01-05
# ..   ...                        ...         ...
# 226  226     Magic Moments Toy Shop  2024-06-27
# 227  227     Magic Moments Toy Shop  2024-06-28
# 228  228          Twinkle Town Toys  2024-06-28
# 229  229     Magic Moments Toy Shop  2024-06-28
# 230  230  Playful Pals Toy Emporium  2024-06-29
#
#                                               feedback   Cost  Shipping  \
# 0    Packaging could be improved to reduce waste an...   9.89     71.35
# 1    Unfortunately, shipping was delayed without pr...   8.92     73.86
# 2    Shipping costs were reasonable compared to ind...  46.60     35.06
# 3    There was a lack of proactive communication ab...  25.00     25.00
# ...
